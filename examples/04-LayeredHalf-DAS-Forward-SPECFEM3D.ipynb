# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline

# %% [markdown]
# ## Install SPECFEM3D
# Please refer to: https://github.com/SPECFEM/specfem3d

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
from IPython.display import Image

from scipy.interpolate import griddata, splprep, splev
from scipy.ndimage import gaussian_filter
from scipy import signal

import utm

# %%
# Creating a grid for interpolation
lons = np.linspace(0, 10000, 200)
lats = np.linspace(0, 10000, 200)
grid_lon, grid_lat = np.meshgrid(lons, lats)

# Interpolating elevation data using real elevation values (previously computed in grid_elev)
# Assume grid_elev has been computed already as follows:
# grid_elev = griddata((lon, lat), elev, (grid_lon, grid_lat), method='cubic')
#
# Prepare the points for interpolation by flattening the grid arrays:
points = np.column_stack((grid_lon.ravel(), grid_lat.ravel()))
values = grid_elev.ravel()

# Create a (n,2) array for the cable points where interpolation is to be performed:
xi = np.column_stack((cable_smoothed[:, 0], cable_smoothed[:, 1]))

# Now interpolate to obtain the cable elevation.
cable_elev = griddata(points, values, xi, method='cubic')

# Combine the interpolated elevations with the cable coordinates
cable_coord = np.concatenate((cable_smoothed, cable_elev.reshape(-1, 1)), axis=1)

# Remove NaNs at the boundary using slicing (if needed)
grid_elev[:5, :]  = grid_elev[5, None, :]
grid_elev[-5:, :] = grid_elev[-5, None, :]
grid_elev[:, :5]  = grid_elev[:, 5, None]
grid_elev[:, -5:] = grid_elev[:, -5, None]

# %%
# Creating the plot
fig = plt.figure(figsize=(8, 6))
plt.pcolor(grid_lon, grid_lat, grid_elev)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Design the fiber cable trajectory

# %%
cable = []
max_elevation_idx = np.argmax(elev)
# cable.append([lon[max_elevation_idx-1], lat[max_elevation_idx-1]])
cable.append([lons[50*2], lats[45*2]])
cable.append([lons[47*2], lats[42*2]])
cable.append([lons[44*2], lats[40*2]])
cable.append([lons[40*2], lats[35*2]])
cable.append([lons[42*2], lats[30*2]])
cable.append([lons[48*2], lats[28*2]])
cable.append([lons[55*2], lats[27*2]])
cable.append([lons[60*2], lats[26*2]])
cable.append([lons[65*2], lats[25*2]])
cable.append([lons[70*2], lats[22*2]])
cable.append([lons[75*2], lats[19*2]])
cable.append([lons[80*2], lats[19*2]])
cable.append([lons[85*2], lats[20*2]])
cable.append([lons[90*2], lats[22*2]])
cable.append([lons[95*2], lats[24*2]])
# cable.append([lons[98*2], lats[26*2]])
cable = np.array(cable)

# %%
# Number of points to interpolate - more points mean a smoother curve
num_points = 2500

# Preparing the data for spline fitting (using all coordinates)
tck, _ = splprep([cable[:,0], cable[:,1]], s=0)

# Generating new, smoothed points from the spline representation
cable_smoothed = splev(np.linspace(0, 1, num_points), tck)

cable_smoothed = np.array(cable_smoothed).T

# %%
# Creating the plot
fig, ax = plt.subplots(figsize=(8, 6))
cax = ax.pcolor(grid_lon, grid_lat, grid_elev)
ax.plot(cable_smoothed[:,0], cable_smoothed[:,1], '-r')
ax.set_aspect('equal')
plt.colorbar(cax)
plt.show()

# %% [markdown]
# ## Elevation of the fiber cable

# %%
# Prepare a (n, 2) array of grid coordinates
points = np.column_stack((grid_lon.ravel(), grid_lat.ravel()))

# Flatten the elevation values to correspond to the points
values = grid_elev.ravel()

# Prepare the interpolation points from your cable_smoothed array
xi = np.column_stack((cable_smoothed[:, 0], cable_smoothed[:, 1]))

# Now interpolate to obtain the cable elevation
cable_elev = griddata(points, values, xi, method='cubic')

# Combine the interpolated elevations with the cable coordinates
cable_coord = np.concatenate((cable_smoothed, cable_elev.reshape(-1, 1)), axis=1)

# %%
plt.plot(cable_elev)

# %% [markdown]
# ## Plot the topography with the fiber cable

# %%
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(111, projection='3d')

# Plotting the trajectory line first so it appears in front
ax.plot(cable_coord[:,0], cable_coord[:,1], cable_coord[:,2], color='red', linewidth=1, linestyle='-', zorder=5)

# Surface plot with colormap
surf = ax.plot_surface(grid_lon, grid_lat, grid_elev, cmap='terrain', vmin=grid_elev.min(), vmax=grid_elev.max(), zorder=0)

# Labels and title
ax.set_xlabel('Easting', fontsize=12, labelpad=8)
ax.set_ylabel('Northing', fontsize=12, labelpad=8)
ax.set_zlabel('Elevation (m)', fontsize=12, labelpad=8)
ax.set_box_aspect((1, 1, 0.2))  # Adjusted Z-axis for better visibility
plt.colorbar(surf, shrink=0.5, aspect=40, pad=0.1)

plt.show()

# %% [markdown]
# ## Generic Cable

# %%
# !pwd
# Out:
# /home/masa/DAS_GenericCable/examples

# %%
from genericcable import GenericCable

# %%
traj = cable_coord.copy()
traj[:,2] = -traj[:,2]
# set large length for better plotting
chann_len = 20.0
chann_num = 679
gauge_len = 20.0

# %%
cable = GenericCable(traj, chann_len, chann_num, gauge_len)
# Out:
# Last channel length must be between 10.0 and 7667.731555790342 m, it is 13590.0 m
# Change the channel number to 383 to make sure the last channel ends at the end of the cable

# %%
cable
# Out:
# DAS Cable Information:
#   Cable total length: 7677.73 m
#   Channel coverage: 10.00 - 7670.00 m
#   Channel interval: 20.00 m
#   Channel number: 383
#   Gauge length: 20.00 m
#   Max channel length error: 0.0254 m
#   Max  gauge  length error: 0.0253 m

# %%
chan_coord = cable.get_chann_coords()

# %%
chan_coord.shape
# Out:
# (383, 3)

# %%
## Smooth the sensitivies
cable.tan_cha[:,0] = gaussian_filter(cable.tan_cha[:,0], sigma=2)
cable.tan_cha[:,1] = gaussian_filter(cable.tan_cha[:,1], sigma=2)
cable.tan_cha[:,2] = gaussian_filter(cable.tan_cha[:,2], sigma=2)

# %%
cable.plot_traj()

# %%
cable.plot_channel(show_tangent=True)

# %%
cable.plot_sensitivity()

# %%
tan = cable.tan_cha
cha = cable.traj_cha

# Use the correct number of channels from the cable sensitivity data
n_channels = cable.tan_cha.shape[0]
length = np.arange(n_channels) * chann_len / 1000

fig, ax = plt.subplots(figsize=(9, 3))

# Increase line width and use different line styles
ax.plot(length, tan[:, 0], label='Easting',  linewidth=2, linestyle='-')
ax.plot(length, tan[:, 1], label='Northing', linewidth=2, linestyle='-')
ax.plot(length, tan[:, 2], label='Z',        linewidth=2, linestyle='-')

# Enhance labels and title
ax.set_xlabel('Cable Length (km)', fontsize=16)
ax.set_ylabel('Sensitivity', fontsize=16)

# Refine grid and axes
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.set_xlim([min(length), max(length)])
ax.set_ylim([-1.2, 1.2])

# Improve the legend
ax.legend(frameon=True, loc='best', fontsize=12)

# Adjust font sizes
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(10)
ax.tick_params(axis='both', which='major', labelsize=14)  # Adjust labelsize as needed

# Save the plot with high resolution
plt.savefig('sensitivity.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(111, projection='3d')

# Plotting the trajectory line
ax.plot(cable_coord[:,0], cable_coord[:,1], cable_coord[:,2], color='red', linewidth=1, linestyle='-', zorder=5)

# Surface plot with colormap
surf = ax.plot_surface(grid_lon, grid_lat, grid_elev, cmap='terrain', vmin=grid_elev.min(), vmax=grid_elev.max(), zorder=4)

# Plot some lables
chan_coord_plot = chan_coord[::100,:]
ax.plot(chan_coord_plot[:,0], chan_coord_plot[:,1], -chan_coord_plot[:,2], 'k.', markersize = 2, alpha=1.0, zorder=5)
for i in range(chan_coord_plot.shape[0]):
    ax.text(chan_coord_plot[i,0] + 700, chan_coord_plot[i,1], -chan_coord_plot[i,2], f'{i*2} km', fontsize=8, zorder=4)

# Labels and title
ax.set_xlabel('Easting', fontsize=12, labelpad=12)
ax.set_ylabel('Northing', fontsize=12, labelpad=12)
ax.set_zlabel('Elevation (m)', fontsize=12, labelpad=8)
ax.set_box_aspect((1, 1, 0.2))  # Adjusted Z-axis for better visibility
plt.colorbar(surf, shrink=0.35, aspect=40, pad=-0.20, orientation='horizontal')
ax.view_init(elev=18, azim=-45)

plt.tight_layout()
plt.savefig('topo.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(111, projection='3d')

# Plotting the trajectory line
ax.plot(cable_coord[:,0], cable_coord[:,1], cable_coord[:,2], color='red', linewidth=1, linestyle='-', zorder=5)

# Surface plot with colormap
surf = ax.plot_surface(grid_lon, grid_lat, grid_elev, cmap='terrain', vmin=grid_elev.min(), vmax=grid_elev.max(), zorder=4)

# Plot some lables
chan_coord_plot = chan_coord[::100,:]
ax.plot(chan_coord_plot[:,0], chan_coord_plot[:,1], -chan_coord_plot[:,2], 'k.', markersize = 2, alpha=1.0, zorder=5)
for i in range(chan_coord_plot.shape[0]):
    ax.text(chan_coord_plot[i,0] + 700, chan_coord_plot[i,1], -chan_coord_plot[i,2], f'{i*2} km', fontsize=8, zorder=4)

# Labels and title
ax.set_xlabel('Easting', fontsize=12, labelpad=12)
ax.set_ylabel('Northing', fontsize=12, labelpad=12)
ax.set_zlabel('Elevation (m)', fontsize=12, labelpad=8)
ax.set_box_aspect((1, 1, 0.35))  # Adjusted Z-axis for better visibility
ax.tick_params(axis='both', which='major', labelsize=10)  # Adjust labelsize as needed

plt.colorbar(surf, shrink=0.35, aspect=40, pad=-0.05, orientation='horizontal')
# ax.view_init(elev=18, azim=-45)

plt.tight_layout()
plt.savefig('topo2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# # Function to update the plot for each frame
# def update_plot(angle):
#     ax.view_init(elev=30, azim=angle)

# # Create figure and 3D axis
# fig = plt.figure(figsize=(16, 9))
# ax = fig.add_subplot(111, projection='3d')

# # Plotting the trajectory line
# ax.plot(cable_coord[:,0], cable_coord[:,1], cable_coord[:,2], color='red', linewidth=1, linestyle='-', zorder=5)

# # Surface plot with colormap
# surf = ax.plot_surface(grid_lon, grid_lat, grid_elev, cmap='terrain', vmin=grid_elev.min(), vmax=grid_elev.max(), zorder=4)

# # Plot some lables
# chan_coord_plot = chan_coord[::100,:]
# ax.plot(chan_coord_plot[:,0], chan_coord_plot[:,1], -chan_coord_plot[:,2], 'k.', markersize = 2, alpha=1.0, zorder=5)
# for i in range(chan_coord_plot.shape[0]):
#     ax.text(chan_coord_plot[i,0] + 700, chan_coord_plot[i,1], -chan_coord_plot[i,2], f'{i*2} km', fontsize=8, zorder=4)

# # Labels and title
# ax.set_xlabel('Easting', fontsize=12, labelpad=8)
# ax.set_ylabel('Northing', fontsize=12, labelpad=8)
# ax.set_zlabel('Elevation (m)', fontsize=12, labelpad=8)
# ax.set_box_aspect((1, 1, 0.28))  # Adjusted Z-axis for better visibility
# plt.colorbar(surf, shrink=0.5, aspect=40, pad=0.1)

# plt.show()
# # Your plotting code here (plotting trajectory line, labels, surface plot, etc.)

# # Animation
# ani = animation.FuncAnimation(fig, update_plot, frames=np.arange(0, 360, 1), interval=50)
# ani.save('3d_plot_animation.gif', writer='imagemagick')

# plt.close(fig) # Prevents duplicate display of the last frame

# %%
cable.dot_product_test()
# Out:
# **********************************************
# Dot-product test:
#   Input waveform comp: vel, DAS comp: strain_rate
#   lhs = 3.70993893e+00
#   rhs = 3.70993893e+00
#   absolute error = 4.44089210e-16
#   relative error = 1.19702566e-16
#
# **********************************************
# Dot-product test:
#   Input waveform comp: vel, DAS comp: strain
#   lhs = 1.61816999e-01
#   rhs = 1.61816999e-01
#   absolute error = 0.00000000e+00
#   relative error = 0.00000000e+00
#
# **********************************************
# Dot-product test:
#   Input waveform comp: disp, DAS comp: strain_rate
#   lhs = 2.32554000e+02
#   rhs = 2.32554000e+02
#   absolute error = 8.81072992e-13
#   relative error = 3.78868131e-15
#
# **********************************************
# Dot-product test:
#   Input waveform comp: disp, DAS comp: strain
#   lhs = 5.38136918e+00
#   rhs = 5.38136918e+00
#   absolute error = 0.00000000e+00
#   relative error = 0.00000000e+00

# %%
rec_loc = cable.get_rec_loc_unique()

# %%
# Example conversion factors (you should set these based on your data)
easting_offset = 500000   # A typical central value in UTM easting
northing_offset = 0       # Adjust as needed for your area
scale_factor = 1000000    # Scale factor to stretch [0, 1] to [0, 1e6]

rec_loc_lonlat = []
for i in range(rec_loc.shape[0]):
    easting = rec_loc[i, 0] * scale_factor + easting_offset
    northing = rec_loc[i, 1] * scale_factor + northing_offset
    rec_loc_lonlat.append(utm.to_latlon(easting, northing, 10, zone_letter='T'))

rec_loc_lonlat = np.array(rec_loc_lonlat)
# Out:
# ---------------------------------------------------------------------------
# OutOfRangeError                           Traceback (most recent call last)
# Cell In[191], line 10
#       8     easting = rec_loc[i, 0] * scale_factor + easting_offset
#       9     northing = rec_loc[i, 1] * scale_factor + northing_offset
# ---> 10     rec_loc_lonlat.append(utm.to_latlon(easting, northing, 10, zone_letter='T'))
#      12 rec_loc_lonlat = np.array(rec_loc_lonlat)
#
# File ~/miniconda3/envs/pysep/lib/python3.10/site-packages/utm/conversion.py:125, in to_latlon(easting, northing, zone_number, zone_letter, northern, strict)
#     123 if strict:
#     124     if not in_bounds(easting, 100000, 1000000, upper_strict=True):
# --> 125         raise OutOfRangeError('easting out of range (must be between 100,000 m and 999,999 m)')
#     126     if not in_bounds(northing, 0, 10000000):
#     127         raise OutOfRangeError('northing out of range (must be between 0 m and 10,000,000 m)')
#
# OutOfRangeError: easting out of range (must be between 100,000 m and 999,999 m)

# %%
plt.plot(rec_loc_lonlat[:, 0], rec_loc_lonlat[:, 1], '-r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 plt.plot(rec_loc_lonlat[:, 0], rec_loc_lonlat[:, 1], '-r')
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# ## Write the station file for SPECFEM3D

# %%
with open('/home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/DATA/STATIONS', 'w') as file:
    # Iterate over the points, the topography is not needed
    for i in range(rec_loc_lonlat.shape[0]):
        lon = rec_loc_lonlat[i,0]
        lat = rec_loc_lonlat[i,1]
        file.write(f"STA{i+1:03} \t DAS \t {lon:.4f} \t {lat:.4f} \t 0.0 \t 0.0\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[192], line 3
#       1 with open('/home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/DATA/STATIONS', 'w') as file:
#       2     # Iterate over the points, the topography is not needed
# ----> 3     for i in range(rec_loc_lonlat.shape[0]):
#       4         lon = rec_loc_lonlat[i,0]
#       5         lat = rec_loc_lonlat[i,1]
#
# AttributeError: 'list' object has no attribute 'shape'

# %% [markdown]
# ### Check the receiver information from the SPECFEM code

# %%
def load_vtk_file(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()
    
    # Find the start of the points data
    start_idx = 0
    for i, line in enumerate(lines):
        if line.strip().startswith('POINTS'):
            start_idx = i + 1
            break
    
    # Read the points data
    start_idx += 1 # the first location is the source
    points_data = lines[start_idx:-1]
    points = [list(map(float, line.split())) for line in points_data]
    return np.array(points)

# %%
rec_specfem = load_vtk_file("/home/masa/specfem3d/EXAMPLES/applications/layered_halfspace/OUTPUT_FILES/sr.vtk")

# %%
rec_loc_lonlat.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 rec_loc_lonlat.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
rec_specfem.shape
# Out:
# (2, 3)

# %%
plt.plot(rec_specfem[:, 0], rec_specfem[:, 1], '-r')

# %%
rec_loc.shape
# Out:
# (384, 3)

# %%
rec_specfem.shape
# Out:
# (2, 3)

# %%
plt.plot(rec_loc[:, 0], rec_loc[:, 1], '-r')
plt.plot(rec_specfem[:, 0], rec_specfem[:, 1], '--b')

# %%
# # plt.scatter(rec_loc[:,0], rec_loc[:,1], c = rec_loc[:,2])
# plt.scatter(rec_specfem[:,0], rec_specfem[:,1], c = rec_loc[:,2] + rec_specfem[:,2])

# plt.colorbar()

# %%
plt.hist(rec_loc[:,2] + rec_specfem[:,2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 plt.hist(rec_loc[:,2] + rec_specfem[:,2])
#
# ValueError: operands could not be broadcast together with shapes (384,) (2,)

# %%
plt.figure(figsize=(16, 6))
plt.plot(rec_loc[:,2], label='DAS')
plt.plot(-rec_specfem[:,2], label='SEM')
# plt.xlim([400, 600])
# plt.ylim([-1300, -1050])
plt.legend()
plt.show()

# %%
nrec = rec_loc.shape[0]

# %%
nrec
# Out:
# 384

# %% [markdown]
# ## DAS waveform

# %%
data_vx = []
data_vy = []
data_vz = []

for i in range(nrec):
    # double check the comp
    vx = np.loadtxt(f"/home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/OUTPUT_FILES/DAS.STA{i+1:03}.HXE.semv")
    vy = np.loadtxt(f"/home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/OUTPUT_FILES/DAS.STA{i+1:03}.HXN.semv") 
    vz = np.loadtxt(f"/home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/OUTPUT_FILES/DAS.STA{i+1:03}.HXZ.semv") 
    tt = vz[:,0]
    data_vx.append(vx[:,1])
    data_vy.append(vy[:,1])
    data_vz.append(vz[:,1])

t = tt - tt[0]
data_vel = np.array([data_vx, data_vy, data_vz])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[205], line 7
#       3 data_vz = []
#       5 for i in range(nrec):
#       6     # double check the comp
# ----> 7     vx = np.loadtxt(f"/home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/OUTPUT_FILES/DAS.STA{i+1:03}.HXE.semv")
#       8     vy = np.loadtxt(f"/home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/OUTPUT_FILES/DAS.STA{i+1:03}.HXN.semv")
#       9     vz = np.loadtxt(f"/home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/OUTPUT_FILES/DAS.STA{i+1:03}.HXZ.semv")
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /home/masa/specfem3d/EXAMPLES/applications/Mount_StHelens/OUTPUT_FILES/DAS.STA001.HXE.semv not found.

# %%
# data_ux = []
# data_uy = []
# data_uz = []

# for i in range(nrec):
#     # double check the comp
#     ux = np.loadtxt(f"./OUTPUT_FILES/DAS.STA{i+1:03}.HXE.semd")
#     uy = np.loadtxt(f"./OUTPUT_FILES/DAS.STA{i+1:03}.HXN.semd")
#     uz = np.loadtxt(f"./OUTPUT_FILES/DAS.STA{i+1:03}.HXZ.semd")
#     t = uz[:,0]
#     data_vx.append(ux[:,1])
#     data_vy.append(uy[:,1])
#     data_vz.append(uz[:,1])

# data_dis = np.array([data_ux, data_uy, data_uz])

# %%
data_vel.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 data_vel.shape
#
# NameError: name 'data_vel' is not defined

# %%
plt.imshow(data_vel[0,:,:].T, aspect='auto')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 plt.imshow(data_vel[0,:,:].T, aspect='auto')
#       2 plt.colorbar()
#
# NameError: name 'data_vel' is not defined

# %%
plt.imshow(data_vel[1,:,:].T, aspect='auto')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 plt.imshow(data_vel[1,:,:].T, aspect='auto')
#       2 plt.colorbar()
#
# NameError: name 'data_vel' is not defined

# %%
plt.imshow(data_vel[2,:,:].T, aspect='auto')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[209], line 1
# ----> 1 plt.imshow(data_vel[2,:,:].T, aspect='auto')
#       2 plt.colorbar()
#
# NameError: name 'data_vel' is not defined

# %%
data_das = cable.forward(data_vel, m_comp='vel', d_comp = 'strain_rate')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 data_das = cable.forward(data_vel, m_comp='vel', d_comp = 'strain_rate')
#
# NameError: name 'data_vel' is not defined

# %%
plt.imshow(data_das, aspect='auto')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 plt.imshow(data_das, aspect='auto')
#       2 plt.colorbar()
#
# NameError: name 'data_das' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_wiggle(data, t, scale=1.0):
    """
    Plots a wiggle plot for seismic data.

    Parameters:
    data (2D numpy array): The seismic data array.
    scale (float): Scale factor for the amplitudes.
    """
    n_channels, n_times = data.shape
    fig = plt.figure(figsize=(12, 9))

    for i, trace in enumerate(data):
        trace = trace * scale + i
        plt.plot(trace, range(n_times), color='black', linewidth=1.0)
        plt.fill_betweenx(range(n_times), i, trace, where=(trace > i), color='black')

    plt.ylabel('Time')
    plt.xlabel('Channel Index')
    plt.gca().invert_yaxis()  # Inverts the y-axis to match seismic plot conventions
    plt.show()

# %%
plot_wiggle(data_vel[0,::25,:], t, scale = 5e2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 plot_wiggle(data_vel[0,::25,:], t, scale = 5e2)
#
# NameError: name 'data_vel' is not defined

# %%
plot_wiggle(data_vel[1,::25,:], t, scale = 5e2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 plot_wiggle(data_vel[1,::25,:], t, scale = 5e2)
#
# NameError: name 'data_vel' is not defined

# %%
plot_wiggle(data_vel[2,::25,:], t, scale = 5e2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 plot_wiggle(data_vel[2,::25,:], t, scale = 5e2)
#
# NameError: name 'data_vel' is not defined

# %%
tan = cable.tan_cha
cha = cable.traj_cha

length = np.arange(chann_num) * chann_len / 1000

fig, ax = plt.subplots(figsize=(9, 3))

# Increase line width and use different line styles
ax.plot(length, tan[:,0], label='Easting',  linewidth=2, linestyle='-')
ax.plot(length, tan[:,1], label='Northing', linewidth=2, linestyle='-')
ax.plot(length, tan[:,2], label='Z',        linewidth=2, linestyle='-')

# Enhance labels and title
ax.set_xlabel('Cable Length (km)', fontsize=16)
ax.set_ylabel('Sensitivity', fontsize=16)

# Refine grid and axes
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.set_xlim([min(length), max(length)])
ax.set_ylim([-1.2, 1.2])

# Improve the legend
ax.legend(frameon=True, loc='best', fontsize=12)

# Adjust font sizes
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(10)
ax.tick_params(axis='both', which='major', labelsize=14)  # Adjust labelsize as needed

# Save the plot with high resolution
plt.savefig('sensitivity.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[216], line 9
#       6 fig, ax = plt.subplots(figsize=(9, 3))
#       8 # Increase line width and use different line styles
# ----> 9 ax.plot(length, tan[:,0], label='Easting',  linewidth=2, linestyle='-')
#      10 ax.plot(length, tan[:,1], label='Northing', linewidth=2, linestyle='-')
#      11 ax.plot(length, tan[:,2], label='Z',        linewidth=2, linestyle='-')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (679,) and (383,)

# %%
plot_wiggle(data_das[::5,:], t, scale = 1e6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 plot_wiggle(data_das[::5,:], t, scale = 1e6)
#
# NameError: name 'data_das' is not defined

# %%
extent = [length[0], length[-1], t[-1], t[0]]

vmax = data_das.max() * 0.05

fig, ax = plt.subplots(figsize=(9, 6))
plt.imshow(data_das.T, aspect='auto', extent=extent, cmap='seismic', vmin=-vmax, vmax=vmax)
ax.set_xlabel('Cable Length (km)', fontsize=16)
ax.set_ylabel('Time (m)', fontsize=16)
# Refine grid and axes
ax.grid(True, which='both', linestyle='-', linewidth=0.5)
ax.tick_params(axis='both', which='major', labelsize=14)  # Adjust labelsize as needed

# Save the plot with high resolution
plt.savefig('waveform.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[218], line 1
# ----> 1 extent = [length[0], length[-1], t[-1], t[0]]
#       3 vmax = data_das.max() * 0.05
#       5 fig, ax = plt.subplots(figsize=(9, 6))
#
# NameError: name 't' is not defined

# %%
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 t
#
# NameError: name 't' is not defined
